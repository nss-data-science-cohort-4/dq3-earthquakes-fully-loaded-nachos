# %% [markdown]
# # TN Earthquake preparedness

# %% [markdown]
# # FACT: Earthquakes don’t kill people, buildings and their contents do, and secondary effects do.

# %%
1. Is it advisable to concentrate our resources in the four major metropolitan areas (Memphis, Nashville, Chattanooga, Knoxville)?

# %% [markdown]
# Earth quake haven't killed anyone in TN

# %% [markdown]
# TN E P P
# Call out scenario for new madrid fault quake and fall out, but also mentioned that appalachian fault is just ask likely.

# %%
Which area is likely to experience an earthquake?

# %% [markdown]
# maggies bad ass heat map from <08_p2q1_tn_eq_by_region> map: tenn_map

# %% [markdown]
# 08_p2q1_tn_eq_by_region Earthquake count by TDOT Region graph

# %% [markdown]
# Which area is likely to suffer loss from an earthquake if one hits? TEMA data points?

# %% [markdown]
#  Memphis - the bad one preparedness due to fault, river, and population density.
