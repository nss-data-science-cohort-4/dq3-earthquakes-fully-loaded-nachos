# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster, HeatMap, HeatMapWithTime, FastMarkerCluster
import ipywidgets as widgets
import geopandas as gpd
import fiona
import json
import plotly.express as px
gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'
from IPython.display import HTML, display
from collections import defaultdict
from shapely.geometry import Point
pd.set_option('display.max_rows', 999)

# %% [markdown]
# https://ocefpaf.github.io/python4oceanographers/blog/2014/05/05/folium/<br>
# https://github.com/jasonamyers/nss-geospatial-project-1/blob/master/notebooks/Permits%20by%20District.ipynb<br>
# https://eric.clst.org/tech/usgeojson/<br>
# ### Tennessee counties by region is a standalone data file

# %%
tenn_eq = pd.read_csv('../Data/tenn_eq.csv')

# %%
tn_county_region = pd.read_csv('../Data/tn_county_region.csv')
tn_county_region.head()
# Out:
#   county_name  tdot_region  tdot_code
# 0    Anderson            1          1
# 1     Bedford            3          2
# 2      Benton            4          3
# 3     Bledsoe            2          4
# 4      Blount            1          5

# %%
tn_county_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   county_name  95 non-null     object
#  1   tdot_region  95 non-null     int64
#  2   tdot_code    95 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 2.4+ KB

# %%
#Correct a misspelling
#tn_county_region[tn_county_region['county_name']=='Dekalb']['county_name']
tn_county_region.loc[tn_county_region['county_name']=='Dekalb', 'county_name'] = 'DeKalb'

# %%
#Get the boundaries of all US counties
us_county_path = '../Data/gz_2010_us_050_00_500k.json'
cur_json = json.load(open(us_county_path, encoding='ISO-8859-1'))
#path,ext = os.path.splitext(us_county_path)
path,ext = us_county_path.rsplit('.', 1)
new_path =path+"_new"+ext
with open(new_path,"w", encoding='utf-8') as jsonfile:
        json.dump(cur_json,jsonfile,ensure_ascii=False)
us_county = gpd.read_file(new_path, driver='GeoJSON')
#What are our columns?
us_county.columns
# Out:
# Index(['GEO_ID', 'STATE', 'COUNTY', 'NAME', 'LSAD', 'CENSUSAREA', 'geometry'], dtype='object')

# %%
#What does this dataset look like?
us_county.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 3221 entries, 0 to 3220
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   GEO_ID      3221 non-null   object
#  1   STATE       3221 non-null   object
#  2   COUNTY      3221 non-null   object
#  3   NAME        3221 non-null   object
#  4   LSAD        3221 non-null   object
#  5   CENSUSAREA  3221 non-null   float64
#  6   geometry    3221 non-null   geometry
# dtypes: float64(1), geometry(1), object(5)
# memory usage: 176.3+ KB

# %%
#Look at some data
us_county.head()
# Out:
#            GEO_ID STATE COUNTY       NAME    LSAD  CENSUSAREA  \
# 0  0500000US01029    01    029   Cleburne  County     560.100
# 1  0500000US01031    01    031     Coffee  County     678.972
# 2  0500000US01037    01    037      Coosa  County     650.926
# 3  0500000US01039    01    039  Covington  County    1030.456
# 4  0500000US01041    01    041   Crenshaw  County     608.840
#
#                                             geometry
# 0  POLYGON ((-85.38872 33.91304, -85.38089 33.873...
# 1  POLYGON ((-86.03044 31.61894, -86.00409 31.619...
# 2  POLYGON ((-86.00928 33.10164, -86.00917 33.090...
# 3  POLYGON ((-86.34851 30.99434, -86.35023 30.994...
# 4  POLYGON ((-86.14699 31.68045, -86.14711 31.663...

# %%
#Which state is Tennessee?
us_county[us_county['NAME'] == 'Obion']
# Out:
#               GEO_ID STATE COUNTY   NAME    LSAD  CENSUSAREA  \
# 2512  0500000US47131    47    131  Obion  County     544.728
#
#                                                geometry
# 2512  POLYGON ((-88.85526 36.50267, -88.83463 36.502...

# %%
#We only want Tenn
tenn_county = us_county[us_county['STATE'] == '47']

# %%
#Merge in our tdot region data
tenn_county_region = tenn_county.merge(tn_county_region, left_on='NAME', right_on='county_name', how='inner')
#Make sure we still have all 95 counties
tenn_county_region.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 95 entries, 0 to 94
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GEO_ID       95 non-null     object
#  1   STATE        95 non-null     object
#  2   COUNTY       95 non-null     object
#  3   NAME         95 non-null     object
#  4   LSAD         95 non-null     object
#  5   CENSUSAREA   95 non-null     float64
#  6   geometry     95 non-null     geometry
#  7   county_name  95 non-null     object
#  8   tdot_region  95 non-null     int64
#  9   tdot_code    95 non-null     int64
# dtypes: float64(1), geometry(1), int64(2), object(6)
# memory usage: 8.2+ KB

# %%
#Hey look, pretty colors
tenn_county_region.plot('tdot_region');

# %%
#Hey look, useful polygons, thanks Jason!
tenn_county_region.dissolve('tdot_region').plot();

# %%
#Pull out our polygons to use in a map overlay
tenn_region_poly = tenn_county_region.dissolve('tdot_region')['geometry']

# %%
#tenn_region_poly
#type(tenn_region_poly)

# %%
#Check out our eq data
tenn_eq.head()
# Out:
#                        time   latitude  longitude  depth   mag magType   nst  \
# 0  2020-10-25T17:18:57.880Z  35.666833 -84.024667  18.54  2.45      md  23.0
# 1  2020-10-19T20:19:38.490Z  36.224000 -82.817167  17.27  2.31      md   8.0
# 2  2020-10-17T07:12:44.060Z  35.366833 -85.213500  17.99  2.26      md  16.0
# 3  2020-10-09T20:24:02.590Z  36.101833 -83.637833  16.48  2.30      md  14.0
# 4  2020-09-13T11:45:06.680Z  35.706333 -83.916833  18.34  2.47      md  22.0
#
#     gap    dmin   rms  ...                   updated  \
# 0  80.0  0.1405  0.18  ...  2020-10-27T15:36:56.862Z
# 1  70.0  0.1751  0.12  ...  2020-10-23T06:52:55.336Z
# 2  59.0  0.1587  0.14  ...  2020-10-17T13:54:48.250Z
# 3  83.0  0.2041  0.11  ...  2020-10-15T02:32:20.631Z
# 4  40.0  0.1259  0.16  ...  2020-09-26T09:49:46.040Z
#
#                                       place        type horizontalError  \
# 0                                 Tennessee  earthquake            0.31
# 1          6 km N of Greeneville, Tennessee  earthquake            0.91
# 2  4 km NNW of Flat Top Mountain, Tennessee  earthquake            0.33
# 3           7 km W of New Market, Tennessee  earthquake            0.29
# 4           7 km SE of Maryville, Tennessee  earthquake            0.24
#
#   depthError  magError  magNst    status  locationSource magSource
# 0       0.59     0.089    17.0  reviewed              se        se
# 1       1.69     0.099     6.0  reviewed              se        se
# 2       0.60     0.152    15.0  reviewed              se        se
# 3       0.94     0.090    10.0  reviewed              se        se
# 4       0.52     0.080    18.0  reviewed              se        se
#
# [5 rows x 22 columns]

# %%
#Function for geometry
def lat_long_to_point(row):
    return Point(row['longitude'], row['latitude'])

# %%
#Column for geometry
tenn_eq['position'] = tenn_eq.apply(lat_long_to_point, axis=1)

# %%
#Make our geodf
tenn_eq_geo = gpd.GeoDataFrame(tenn_eq, crs='epsg:4326', geometry=tenn_eq['position'])
#And check out the columns
tenn_eq_geo.columns
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource', 'position', 'geometry'],
#       dtype='object')

# %%
#merge in the region data with the eq data
tenn_eq_geo_map = gpd.sjoin(tenn_eq_geo, tenn_county_region, op='within')
#And check out the columns
tenn_eq_geo_map.columns
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource', 'position', 'geometry', 'index_right',
#        'GEO_ID', 'STATE', 'COUNTY', 'NAME', 'LSAD', 'CENSUSAREA',
#        'county_name', 'tdot_region', 'tdot_code'],
#       dtype='object')

# %%
#Base map
tenn_map = folium.Map(tiles='Stamen Terrain', location=[36.224,-82.8171667], zoom_start=6)

# %%
##### Well, this didn't work quite right, so we'll leave it for later. :-)
def color_region(x):
    if x['id'] == '1':
        return {'fillColor': '#7b3294'}
    if x['id'] == '2':
        return {'fillColor': '#c2a5cf'}
    if x['id'] == '3':
        return {'fillColor': '#a6dba0'}
    if x['id'] == '4':
        return {'fillColor': '#008837'}
    print(x)

# %%
#Add in our region polygons, because they are so very cool
folium.GeoJson(tenn_region_poly, lambda x: color_region(x) , overlay=False).add_to(tenn_map)
#{'fillColor': '#A020F0'}
#style_function=color_region

# %%
#Make a heatmap layer with the eq data
heatmapdata = [
    (row['geometry'].y, row['geometry'].x, row['mag']) for idx, row
        in tenn_eq_geo_map.iterrows()
            if row['geometry'] and not pd.isna(row['geometry'].x) and not pd.isna(row['geometry'].y and not pd.isna(row['mag']))
        ]

# %%
#heatmapdata

# %%
hm = HeatMap(data=heatmapdata)
hm.add_to(tenn_map);
tenn_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
tenn_map.save('tn_region_heatmap.html')

# %%
tenn_eq.head()
# Out:
#                        time   latitude  longitude  depth   mag magType   nst  \
# 0  2020-10-25T17:18:57.880Z  35.666833 -84.024667  18.54  2.45      md  23.0
# 1  2020-10-19T20:19:38.490Z  36.224000 -82.817167  17.27  2.31      md   8.0
# 2  2020-10-17T07:12:44.060Z  35.366833 -85.213500  17.99  2.26      md  16.0
# 3  2020-10-09T20:24:02.590Z  36.101833 -83.637833  16.48  2.30      md  14.0
# 4  2020-09-13T11:45:06.680Z  35.706333 -83.916833  18.34  2.47      md  22.0
#
#     gap    dmin   rms  ...        type horizontalError depthError magError  \
# 0  80.0  0.1405  0.18  ...  earthquake            0.31       0.59    0.089
# 1  70.0  0.1751  0.12  ...  earthquake            0.91       1.69    0.099
# 2  59.0  0.1587  0.14  ...  earthquake            0.33       0.60    0.152
# 3  83.0  0.2041  0.11  ...  earthquake            0.29       0.94    0.090
# 4  40.0  0.1259  0.16  ...  earthquake            0.24       0.52    0.080
#
#   magNst    status  locationSource  magSource  \
# 0   17.0  reviewed              se         se
# 1    6.0  reviewed              se         se
# 2   15.0  reviewed              se         se
# 3   10.0  reviewed              se         se
# 4   18.0  reviewed              se         se
#
#                                 position                    geometry
# 0         POINT (-84.0246667 35.6668333)  POINT (-84.02467 35.66683)
# 1             POINT (-82.8171667 36.224)  POINT (-82.81717 36.22400)
# 2            POINT (-85.2135 35.3668333)  POINT (-85.21350 35.36683)
# 3         POINT (-83.6378333 36.1018333)  POINT (-83.63783 36.10183)
# 4  POINT (-83.91683329999999 35.7063333)  POINT (-83.91683 35.70633)
#
# [5 rows x 24 columns]

# %%
tenn_eq['time'] = pd.to_datetime(tenn_eq['time'])

# %%
data_points = []
for idx, row in tenn_eq.sort_values('time').iterrows():
    if row['geometry'] and not pd.isna(row['geometry'].x) and not pd.isna(row['geometry'].y):
        data_points.append((row['time'].to_pydatetime(), row['geometry'].y, row['geometry'].x))
        

by_year=defaultdict(list)
for record in data_points:
    by_year[f'{record[0].strftime("%Y")}'].append([record[1],record[2], 1])
    
over_time = []
time_index = []
for key, values in by_year.items():
    over_time.append(values)
    time_index.append(key)

# %%
tenn_map_heat = folium.Map(tiles='OpenStreetMap', location=[36.224,-82.8171667], zoom_start=6)
folium.GeoJson(tenn_region_poly, lambda x: color_region(x) , overlay=False).add_to(tenn_map_heat)
hm = HeatMapWithTime(data=over_time,
    index=time_index,
    auto_play=False,
    max_opacity=0.3,
    min_speed=4
    )
hm.add_to(tenn_map_heat)

# %%
tenn_map_heat
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
tenn_map_heat.save('tn_timeline.html')

# %%
#Eq's of 2.5 magnitude and over can be detected (i.e., felt by people) without instruments.
tenn_eq['mag'].describe()
# Out:
# count    1076.000000
# mean        1.902063
# std         0.620258
# min         0.000000
# 25%         1.500000
# 50%         1.900000
# 75%         2.282500
# max         4.600000
# Name: mag, dtype: float64

# %%
#Make a df of eq's above 2.5 magnitude
tenn_eq_top_map = tenn_eq_geo_map[tenn_eq_geo_map['mag']> 2.5]

# %%
tenn_eq_top_map.head()
# Out:
#                          time   latitude  longitude  depth   mag magType  \
# 155  2019-01-14T09:00:26.930Z  35.770833 -83.955667  13.01  2.73      md
# 278  2017-07-23T13:22:58.710Z  35.725000 -84.165000  22.57  2.73      md
# 329  2016-10-25T02:42:50.480Z  35.815833 -84.093833   3.32  2.70      md
# 719  2010-04-22T02:14:55.610Z  35.735167 -84.002000   1.67  2.60     mlg
# 721  2010-04-20T09:28:20.040Z  35.725167 -84.001000   2.24  3.30     mlg
#
#       nst   gap     dmin   rms  ... index_right          GEO_ID STATE COUNTY  \
# 155  28.0  33.0  0.16210  0.17  ...           8  0500000US47009    47    009
# 278  19.0  62.0  0.05717  0.16  ...           8  0500000US47009    47    009
# 329  31.0  36.0  0.15570  0.25  ...           8  0500000US47009    47    009
# 719  23.0  40.0      NaN  0.20  ...           8  0500000US47009    47    009
# 721  28.0  41.0      NaN  0.16  ...           8  0500000US47009    47    009
#
#        NAME    LSAD  CENSUSAREA  county_name  tdot_region tdot_code
# 155  Blount  County     558.706       Blount            1         5
# 278  Blount  County     558.706       Blount            1         5
# 329  Blount  County     558.706       Blount            1         5
# 719  Blount  County     558.706       Blount            1         5
# 721  Blount  County     558.706       Blount            1         5
#
# [5 rows x 34 columns]

# %%
tenn_eq_top_map.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 111 entries, 155 to 1070
# Data columns (total 34 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             111 non-null    object
#  1   latitude         111 non-null    float64
#  2   longitude        111 non-null    float64
#  3   depth            108 non-null    float64
#  4   mag              111 non-null    float64
#  5   magType          111 non-null    object
#  6   nst              96 non-null     float64
#  7   gap              96 non-null     float64
#  8   dmin             78 non-null     float64
#  9   rms              96 non-null     float64
#  10  net              111 non-null    object
#  11  id               111 non-null    object
#  12  updated          111 non-null    object
#  13  place            111 non-null    object
#  14  type             111 non-null    object
#  15  horizontalError  96 non-null     float64
#  16  depthError       96 non-null     float64
#  17  magError         94 non-null     float64
#  18  magNst           96 non-null     float64
#  19  status           111 non-null    object
#  20  locationSource   111 non-null    object
#  21  magSource        111 non-null    object
#  22  position         111 non-null    object
#  23  geometry         111 non-null    geometry
#  24  index_right      111 non-null    int64
#  25  GEO_ID           111 non-null    object
#  26  STATE            111 non-null    object
#  27  COUNTY           111 non-null    object
#  28  NAME             111 non-null    object
#  29  LSAD             111 non-null    object
#  30  CENSUSAREA       111 non-null    float64
#  31  county_name      111 non-null    object
#  32  tdot_region      111 non-null    int64
#  33  tdot_code        111 non-null    int64
# dtypes: float64(13), geometry(1), int64(3), object(17)
# memory usage: 30.4+ KB

# %%
tenn_map_top = folium.Map(tiles='Stamen Terrain', location=[36.224,-82.8171667], zoom_start=6)

# %%
folium.GeoJson(tenn_region_poly, lambda x: color_region(x), overlay=False).add_to(tenn_map_top);

# %%
heatmapdata_top = [
    (row['geometry'].y, row['geometry'].x, row['mag']) for idx, row
        in tenn_eq_top_map.iterrows()
            if row['geometry'] and not pd.isna(row['geometry'].x) and not pd.isna(row['geometry'].y and not pd.isna(row['mag']))
        ]

# %%
hm_top = HeatMap(data=heatmapdata_top)

# %%
hm_top.add_to(tenn_map_top);

# %%
tenn_map_top
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Returning to the full data set
tenn_eq_geo_map.groupby(['tdot_region']).count()
# Out:
#              time  latitude  longitude  depth  mag  magType  nst  gap  dmin  \
# tdot_region
# 1             707       707        707    706  707      707  690  690   655
# 2             309       309        309    309  309      309  305  305   289
# 3              21        21         21     21   21       21   15   15    13
# 4              16        16         16     14   16       16    6    6     3
#
#              rms  ...  geometry  index_right  GEO_ID  STATE  COUNTY  NAME  \
# tdot_region       ...
# 1            690  ...       707          707     707    707     707   707
# 2            305  ...       309          309     309    309     309   309
# 3             15  ...        21           21      21     21      21    21
# 4              6  ...        16           16      16     16      16    16
#
#              LSAD  CENSUSAREA  county_name  tdot_code
# tdot_region
# 1             707         707          707        707
# 2             309         309          309        309
# 3              21          21           21         21
# 4              16          16           16         16
#
# [4 rows x 33 columns]

# %%
eq_count_by_region = tenn_eq_geo_map.groupby(['tdot_region'])['mag'].count()

# %%
region_names = pd.Series({'1':'Knoxville','2':'Chattanooga','3':'Nashville','4':'Memphis'})

# %%
count_by_region_name = pd.concat([eq_count_by_region.reset_index(drop=True),region_names.reset_index(drop=True)], axis=1)

# %%
count_by_region_name.columns = ['Count', 'Region']

# %%
eq_region = px.bar(count_by_region_name, x='Region', y='Count', title='Earthquake count by TDOT Region', color='Count', 
                   text='Count', colorscale='Viridis')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-b657d34c9c3a> in <module>
# ----> 1 eq_region = px.bar(count_by_region_name, x='Region', y='Count', title='Earthquake count by TDOT Region', color='Count',
#       2                    text='Count', colorscale='Viridis')
#
# TypeError: bar() got an unexpected keyword argument 'colorscale'

# %%
# !conda install psutil -y

# %%
# !conda install -c plotly plotly-orca -y

# %%
eq_region.update_traces(texttemplate='%{text:.2s}', textposition='outside')
# Out:
# <div>                            <div id="edde332e-b6ca-475e-a166-f3d5a89e7730" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edde332e-b6ca-475e-a166-f3d5a89e7730")) {                    Plotly.newPlot(                        "edde332e-b6ca-475e-a166-f3d5a89e7730",                        [{"alignmentgroup": "True", "hovertemplate": "Region=%{x}<br>Count=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [707, 309, 21, 16], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [707.0, 309.0, 21.0, 16.0], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Knoxville", "Chattanooga", "Nashville", "Memphis"], "xaxis": "x", "y": [707, 309, 21, 16], "yaxis": "y"}],                        {"barmode": "relative", "coloraxis": {"colorbar": {"title": {"text": "Count"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d08 ...

# %%
eq_region
# Out:
# <div>                            <div id="5be3ee64-ef19-447a-badd-aa7280e3959c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5be3ee64-ef19-447a-badd-aa7280e3959c")) {                    Plotly.newPlot(                        "5be3ee64-ef19-447a-badd-aa7280e3959c",                        [{"alignmentgroup": "True", "hovertemplate": "Region=%{x}<br>Count=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [707, 309, 21, 16], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [707.0, 309.0, 21.0, 16.0], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Knoxville", "Chattanooga", "Nashville", "Memphis"], "xaxis": "x", "y": [707, 309, 21, 16], "yaxis": "y"}],                        {"barmode": "relative", "coloraxis": {"colorbar": {"title": {"text": "Count"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d08 ...

# %%
eq_region.write_image('eq_by_region.png')

# %% [markdown]
# # Earthquakes in dataset = 1075
# ## Region 1 (Knoxville) = 706
# ## Region 2 (Chattanooga) = 309
# ## Region 3 (Nashville) = 21
# ## Region 4 (Memphis) = 16

# %%
#Counts by region for eq's over 2.5 magnitude
tenn_eq_top_map.groupby(['tdot_region']).count()

# %% [markdown]
# # Magnitude 2.5+ in dataset = 111
# ## Region 1 (Knoxville) = 72
# ## Region 2 (Chattanooga) = 30
# ## Region 3 (Nashville) = 1
# ## Region 4 (Memphis) = 8
